# %% [markdown]
# Lo primero que hay que hacer es instalar las aplicacion de Python desde el área de aplicaciones para que se pueda trabajar en este archivo.

# %%
pwd  # para saber el área de trabjao donde nos encontramos.
# Out:
# '/workspaces/BashPraxis'

# %%
ls # para ver los archivos que tenemos en el espacio de trabajo.

# %%
ls -l /usr/bin
# Out:
# total 516876
# lrwxrwxrwx 1 root root          28 Apr 20  2020  FileCheck-10 -> ../lib/llvm-10/bin/FileCheck*
# lrwxrwxrwx 1 root root           1 Feb  8  2020  X11 -> ./
# -rwxr-xr-x 1 root root       59736 Sep  5  2019 '['*
# lrwxrwxrwx 1 root root          25 Mar 17 16:55  aclocal -> /etc/alternatives/aclocal*
# -rwxr-xr-x 1 root root       36478 Feb  5  2020  aclocal-1.16*
# -rwxr-xr-x 1 root root        7415 Mar 21  2023  add-apt-repository*
# -rwxr-xr-x 1 root root       30952 Apr  9  2024  addpart*
# lrwxrwxrwx 1 root root          26 Feb  6 16:09  addr2line -> x86_64-linux-gnu-addr2line*
# lrwxrwxrwx 1 root root           6 Feb 25  2020  apropos -> whatis*
# -rwxr-xr-x 1 root root       18824 Oct  6  2023  apt*
# lrwxrwxrwx 1 root root          18 Mar 21  2023  apt-add-repository -> add-apt-repository*
# -rwxr-xr-x 1 root root       88536 Oct  6  2023  apt-cache*
# -rwxr-xr-x 1 root root       31192 Oct  6  2023  apt-cdrom*
# ...

# %%
ls -l /usr/bin | wc -l
# Out:
# 1008

# %%
ls -l /usr/bin | wc -l > binn.txt  # para crear un archivo a paratir de la busqueda.(se debe de poner el terminal o instalar la aplicacion de bash y corre directamente en este archivo.)

# %%
cat bin.txt
# Out:
# 1008

# %%
ls -l /wrongpath && touch newfile.Text # en este caso no sea crea un nuevo archivo porque no exite el archivo mencionado en el directorio.
# Out:
# ls: cannot access '/wrongpath': No such file or directory

# %%
ls
# Out:
# README.md  bash_pip.ipynb  bin.txt  binn.txt  git.ipynb  git.txt  guardar.sh

# %%
ls -l README.md && touch newfile.Text # un archivo con condicional, en este caso si exite Readme.md se crea newfile.txt
# Out:
# -rw-rw-rw- 1 codespace root 126 May 27 15:13 README.md

# %%
ls
# Out:
# README.md       bin.txt   git.ipynb  guardar.sh
# bash_pip.ipynb  binn.txt  git.txt    newfile.Text

# %%
ls -l README.md && touch newfile2.Text
# Out:
# -rw-rw-rw- 1 codespace root 126 May 27 15:13 README.md

# %%
ls -l README.md && touch newfile3.Text
# Out:
# -rw-rw-rw- 1 codespace root 126 May 27 15:13 README.md

# %%
# !STR=$'1. this is a line\n2. This is a line\n3. This is a line.' #

# %%
# !echo "$STR" #En consola

# %%
# !echo "$STR" > lines.txt

# %%
cat lines.txt
# Out:
# 1. this is a line
# 2. This is a line
# 3. This is a line.

# %%
cat lines.txt | sort -r
# Out:
# 3. This is a line.
# 2. This is a line
# 1. this is a line

# %%
cat lines.txt | sort -r | less
# Out:
# 3. This is a line.
# 2. This is a line
# 1. this is a line
# (END)

# %%
cat lines.txt | grep 3 # Para ver la linea 3
# Out:
# 3. This is a line.

# %%
cat lines.txt | grep 3 > match.txt

# %%
cat match.txt
# Out:
# 3. This is a line.

# %%
# !echo "Something" > append.txt

# %%
cat append.txt
# Out:
# Overwrite

# %%
# !echo "Overwrite" > append.txt

# %%
# !echo "Another thing" >> append.txt # para escribir sobre un archivo exitente.

# %%
cat append.txt
# Out:
# Overwrite
# Another thing
# Nuevo código
# Nuevo código

# %%
# !echo "Nuevo código" >> append.txt

# %%
ls -l /wrong/path
# Out:
# ls: cannot access '/wrong/path': No such file or directory

# %%
ls -l /wrong/path 2> /dev/null

# %%
# !tail -f /var/log/lock/log/
# Out:
# tail: cannot open '/var/log/lock/log/' for reading: No such file or directory
# tail: no files remaining

# %%
# !tail -f /var/log/dpkg.log
# Out:
# 2025-03-17 17:12:11 configure libxmlsec1-dev:amd64 1.2.28-2 <none>
# 2025-03-17 17:12:11 status unpacked libxmlsec1-dev:amd64 1.2.28-2
# 2025-03-17 17:12:11 status half-configured libxmlsec1-dev:amd64 1.2.28-2
# 2025-03-17 17:12:11 status installed libxmlsec1-dev:amd64 1.2.28-2
# 2025-03-17 17:12:11 trigproc man-db:amd64 2.9.1-1 <none>
# 2025-03-17 17:12:11 status half-configured man-db:amd64 2.9.1-1
# 2025-03-17 17:12:12 status installed man-db:amd64 2.9.1-1
# 2025-03-17 17:12:12 trigproc libc-bin:amd64 2.31-0ubuntu9.17 <none>
# 2025-03-17 17:12:12 status half-configured libc-bin:amd64 2.31-0ubuntu9.17
# 2025-03-17 17:12:12 status installed libc-bin:amd64 2.31-0ubuntu9.17
# ^C

# %%
# !tail -f -n 2 /var/log/dpkg.log
# Out:
# 2025-03-17 17:12:12 status half-configured libc-bin:amd64 2.31-0ubuntu9.17
# 2025-03-17 17:12:12 status installed libc-bin:amd64 2.31-0ubuntu9.17
# ^C

# %%
# !tail -f -n 2 /var/log/dpkg.log

# %%
# !tail -f -n 2 /var/log/dpkg.log
